# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
Data = pd.read_csv ("diabetes.csv")
Data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#convert Dataset to DataFrame
DF = pd.DataFrame (Data)
DF
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
DF.describe (include='all')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#missing valuese check
DF.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
DF.dropna (how = 'any')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
DF.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#scatter plots for noises!
plt.figure (figsize = (10,6) , dpi = 80)
plt.scatter (DF['Glucose'] , DF['Outcome'] , color = 'mediumslateblue')
plt.xlabel ('Glucose')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('Glucose VS Diabetes')
plt.grid()
plt.show ()

# %%
plt.figure (figsize = (10,6) , dpi = 80)
plt.scatter (DF['BloodPressure'] , DF['Outcome'] , color = 'cornflowerblue')
plt.xlabel ('BloodPressure')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('BloodPressure VS Diabetes')
plt.grid()
plt.show ()

# %%
plt.figure (figsize = (10,6) , dpi = 80)
plt.scatter (DF['SkinThickness'] , DF['Outcome'] , color = 'green')
plt.xlabel ('SkinThickness')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('SkinThickness VS Diabetes')
plt.grid()
plt.show ()

# %%
plt.figure (figsize = (10,6) , dpi = 80)
plt.scatter (DF['Insulin'] , DF['Outcome'] , color = 'purple')
plt.xlabel ('Insulin')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('Insulin VS Diabetes')
plt.grid()
plt.show ()

# %%
plt.figure (figsize = (10,6) , dpi = 80)
plt.scatter (DF['BMI'] , DF['Outcome'] , color = 'orange')
plt.xlabel ('BMI')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('BMI VS Diabetes')
plt.grid()
plt.show ()

# %%
plt.figure (figsize = (10,6) , dpi = 80)
plt.scatter (DF['DiabetesPedigreeFunction'] , DF['Outcome'] , color = 'royalblue')
plt.xlabel ('DiabetesPedigreeFunction')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('DiabetesPedigreeFunction VS Diabetes')
plt.grid()
plt.show ()

# %%
plt.figure (figsize = (10,6) , dpi = 80)
plt.scatter (DF['Age'] , DF['Outcome'] , color = 'goldenrod')
plt.xlabel ('Age')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('Age VS Diabetes')
plt.grid()
plt.show ()

# %%
# from seaborn library with countplot and its height, we can findout frequenty of features and at the end find noises!
plt.figure (figsize = (35,20) , dpi = 90)
ax = sns.countplot (x  = 'Glucose' , data = DF)
plt.xticks (rotation = 90 , fontsize = 20)
plt.yticks (fontsize = 20)
plt.xlabel ('Glucose')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('Glucose VS Diabetes')
plt.grid()
plt.show ()

# 'Glucose' have a normal distribution (Gaussian)!
# normal distribution (Gaussian) show the range of frequenty

# %%
plt.figure (figsize = (35,20) , dpi = 90)
ax = sns.countplot (x  = 'BloodPressure' , data = DF)
plt.xticks (rotation = 90 , fontsize = 20)
plt.yticks (fontsize = 20)
plt.xlabel ('BloodPressure')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('BloodPressure VS Diabetes')
plt.grid()
plt.show ()

# 'BloodPressure' have a normal distribution (Gaussian)!

# %%
plt.figure (figsize = (35,20) , dpi = 90)
ax = sns.countplot (x  = 'SkinThickness' , data = DF)
plt.xticks (rotation = 90 , fontsize = 20)
plt.yticks (fontsize = 20)
plt.xlabel ('SkinThickness')
plt.ylabel ('Diabetes')
plt.legend (['Diabetes'])
plt.title ('SkinThickness VS Diabetes')
plt.grid()
plt.show ()

# %%
DF1 = DF [DF['SkinThickness']>0]
DF2 = DF1 [DF1['SkinThickness']<90]
# maybe SkinThickness > 90 is noise. so deleted this!
DF2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# count of data is 540 but last number of index is 767. so we should reset index.

DF3 = DF2.dropna (how = 'any')
DF3.reset_index (drop = True , inplace = True)
DF3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              1       89             66             23       94  28.1
# 3              0      137             40             35      168  43.1
# 4              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 535            9      170             74             31        0  44.0
# 536           10      101             76             48      180  32.9
# 537            2      122             70             27        0  36.8
# 538            5      121             72             23      112  26.2
# 539            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# start create the model by KNN
x = pd.DataFrame (Data , columns = ['Glucose' , 'BloodPressure' , 'SkinThickness' , 'Insulin' , 'BMI' , 'DiabetesPedigreeFunction' , 'Age']).values
y = DF.Outcome.values.reshape (-1,1)
x
# Out:
# array([[148.   ,  72.   ,  35.   , ...,  33.6  ,   0.627,  50.   ],
#        [ 85.   ,  66.   ,  29.   , ...,  26.6  ,   0.351,  31.   ],
#        [183.   ,  64.   ,   0.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [121.   ,  72.   ,  23.   , ...,  26.2  ,   0.245,  30.   ],
#        [126.   ,  60.   ,   0.   , ...,  30.1  ,   0.349,  47.   ],
#        [ 93.   ,  70.   ,  31.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
x_train , x_test , y_train , y_test = train_test_split (x , y , test_size = 0.3 , random_state = 0)

# %%
# first solution
k = 5  # KNN = 5 ---> it means, choose 5 sample and train model by this 5 sample.
clf = KNeighborsClassifier (k)
clf.fit (x_train , y_train.ravel ())
y_pred = clf.predict(x_test)

# %%
print ('Accuracy:' , metrics.accuracy_score(y_test , y_pred))
# Out:
# Accuracy: 0.7445887445887446

# %%
k = 3  # KNN = 3 ---> it means, choose 5 sample and train model by this 3 sample.
clf = KNeighborsClassifier (k)
clf.fit (x_train , y_train.ravel ())
y_pred = clf.predict(x_test)

# %%
print ('Accuracy:' , metrics.accuracy_score(y_test , y_pred))
# Out:
# Accuracy: 0.70995670995671

# %%
k = 9  # KNN = 9 ---> it means, choose 9 sample and train model by this 9 sample.
clf = KNeighborsClassifier (k)
clf.fit (x_train , y_train.ravel ())
y_pred = clf.predict(x_test)

# %%
print ('Accuracy:' , metrics.accuracy_score(y_test , y_pred))
# Out:
# Accuracy: 0.7532467532467533

# %%
# second solution:(2)
k = 20
Acc = np.zeros ((k))

for i in range (1 , k+1):
    clf = KNeighborsClassifier (n_neighbors = i)
    clf.fit (x_train , y_train.ravel ())
    y_pred = clf.predict(x_test)
    Acc [i-1] = metrics.accuracy_score(y_test , y_pred)
Acc
# Out:
# array([0.61038961, 0.71861472, 0.70995671, 0.74025974, 0.74458874,
#        0.72727273, 0.75324675, 0.75324675, 0.75324675, 0.75324675,
#        0.74891775, 0.74891775, 0.73593074, 0.73160173, 0.73593074,
#        0.74025974, 0.74025974, 0.74025974, 0.73593074, 0.72727273])

# %%
print (np.min (Acc))
print (np.max (Acc))
# Out:
# 0.6103896103896104
# 0.7532467532467533

# %%
# third solution:(3)
training_acc = []
test_acc = []

neighbors_setting = range (1,20)
for n_neighbors in neighbors_setting :
    knn = KNeighborsClassifier (n_neighbors = n_neighbors)
    knn.fit (x_train , y_train.ravel ())
    training_acc.append (knn.score (x_train , y_train))
    test_acc .append (knn.score (x_test , y_test))
plt.figure (figsize = (8,6) , dpi = 80)
plt.plot(neighbors_setting , training_acc , label = 'Accuracy of the training set' ,  color = 'cornflowerblue')
plt.plot(neighbors_setting , test_acc , label = 'Accuracy of the test set' , color = 'orange')
plt.xlabel ('Number of Neighbors')
plt.ylabel ('Accuracy')
plt.legend()
plt.grid()
plt.show ()
